# %%
# match 3
match3_LSG = [
    "KL Rahul",
    "Kyle Mayers",
    "Marcus Stoinis",
    "Deepak Hooda",
    "Krunal Pandya",
    "Nicholas Pooran",
    "Ayush Badoni",
    "Mark Wood",
    "Jaydev Unadkat",
    "Ravi Bishnoi",
    "Avesh Khan",
]

match3_DC = [
    "David Warner",
    "Prithvi Shaw",
    "Mitchell Marsh",
    "Rilee Rossouw",
    "Sarfaraz Khan",
    "Rovman Powell",
    "Axar Patel",
    "Kuldeep Yadav",
    "Chetan Sakariya",
    "Khaleel Ahmed",
    "Mukesh Kumar",
]

# match 4
match4_SRH = [
    "Mayank Agarwal",
    "Abhishek Sharma",
    "Rahul Tripathi",
    "Harry Brook",
    "Glenn Phillips",
    "Washington Sundar",
    "Bhuvneshwar Kumar",
    "Adil Rashid",
    "T Natarajan",
    "Umran Malik",
    "Fazalhaq Farooqi",
]

match4_RR = [
    "Yashasvi Jaiswal",
    "Jos Buttler",
    "Devdutt Padikkal",
    "Sanju Samson",
    "Riyan Parag",
    "Shimron Hetmyer",
    "Jason Holder",
    "Ravichandran Ashwin",
    "Trent Boult",
    "KM Asif",
    "Yuzvendra Chahal",
]
# match 5

match5_RCB = [
    "Virat Kohli",
    "Faf du Plessis",
    "Glenn Maxwell",
    "Michael Bracewell",
    "Shahbaz Ahmed",
    "Dinesh Karthik",
    "Karn Sharma",
    "Harshal Patel",
    "Akash Deep",
    "Reece Topley",
    "Mohammed Siraj",
]
match5_MI = [
    "Rohit Sharma",
    "Ishan Kishan",
    "Suryakumar Yadav",
    "Cameron Green",
    "Tilak Varma",
    "Tim David",
    "Nehal Wadhera",
    "Hrithik Shokeen",
    "Piyush Chawla",
    "Jofra Archer",
    "Arshad Khan",
]
